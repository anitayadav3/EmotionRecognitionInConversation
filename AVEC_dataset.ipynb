# %% [markdown]
# <a href="https://colab.research.google.com/github/anitayadav3/EmotionRecognitionInConversation/blob/master/AVEC_dataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/My Drive/DialogueRNN
# Out:
# /content/drive/My Drive/DialogueRNN

# %%
# !python train_AVEC.py --dropout 0.4 --lr 0.0003 --batch-size 32 --class-weight --l2 0.0
# Out:
# Traceback (most recent call last):
#   File "train_AVEC.py", line 18, in <module>
#     from model import AVECModel, MaskedMSELoss
# ModuleNotFoundError: No module named 'model'

# %%
# import pandas as pd
# import _pickle as cPickle


# f = open('/content/drive/My Drive/datasets/iemocap/IEMOCAP_features_raw.pkl','rb')

# unpickler = cPickle.Unpickler(f)
# unpickler.load()

# %%
labels = open('/content/drive/My Drive/DialogueRNN/AVEC_features/AVEC_features_1.pkl','rb')

unpickleee = pickle.load(labels)
print (labels)
print(unpickleee)

# %%
f = open( "/content/drive/My Drive/DialogueRNN/train.txt")
print(f.readlines())
# Out:
# ['id\tturn1\tturn2\tturn3\tlabel\n', "0\tDon't worry  I'm girl\thmm how do I know if you are\tWhat's ur name?\tothers\n", '1\tWhen did I?\tsaw many times i think -_-\tNo. I never saw you\tangry\n', '2\tBy\tby Google Chrome\tWhere you live\tothers\n', '3\tU r ridiculous\tI might be ridiculous but I am telling the truth.\tU little disgusting whore\tangry\n', '4\tJust for time pass\twt do u do 4 a living then\tMaybe\tothers\n', "5\tI'm a dog person\tyoure so rude\tWhaaaat why\tothers\n", '6\tSo whatsup\tNothing much. Sitting sipping and watching TV. How abt u?\tWhat are you watching on tv?\tothers\n', '7\tOk\tok im back!!\tSo, how are u\tothers\n', '8\tReally?\treally really really really really\tY saying so many times...i can hear you\tothers\n', '9\tBay\tin the bay\t😘 love you\tothers\n', '10\tI hate my boyfriend\tyou got a boyfriend?\tYes\tangry\n', '11\tI will do night.\tAlright. Keep me in loop.\tNot giving WhatsApp no.\tothers\n', '12\tSure go ahead\tMany thanks once again!\tLove 
# ...

# %%
import pandas as pd
import numpy as np
import pickle


videoIDs, videoSpeakers, videoLabels, videoText, videoAudio, videoVisual, videoSentence, trainVid, testVid = pickle.load(open("/content/drive/My Drive/DialogueRNN/AVEC_features/AVEC_features_1.pkl", "rb"), encoding='latin1')
'''
label index mapping = {'hap':0, 'sad':1, 'neu':2, 'ang':3, 'exc':4, 'fru':5}
'''
print(videoSentence)
print(len(testVid))
# Out:
# {2: [b"oh i'd like to speak to poppy please", b"hi i'm poppy have we met before", b'yes poppy what a hollaballoo all that was', b"oh don't worry it won't actually make anything worse in the long run everything will turn out fine you'll see", b"it would need to it's taken us what an hour to get this set up again", b'just think how much longer other things could take', b"i suppose that's right poppy and it is a friday afternoon and a there still time for me to go christmas shopping", b"and we've got a recording set up", b"yes isn't that really really good and you look very nice this afternoon poppy", b"oh thank you i've had my hair done", b"it doesn't look as if you've had it done poppy i i would", b'i had it blow dried', b'ah i would recommend a haircut poppy', b"aw don't you like my hair", b'i suppose it will do do you like mine poppy', b"i think your hair's just lovely i think you have such lovely hair especially in the the colours from this monitor because it's all different", b"<l
# ...
