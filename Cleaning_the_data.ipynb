# %% [markdown]
# <a href="https://colab.research.google.com/github/anitayadav3/EmotionRecognitionInConversation/blob/master/Cleaning_the_data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Notebook including all different types of cleaning/preprocessing of data**

# %%
import pickle
import re
import nltk
from nltk.corpus import stopwords
nltk.download('stopwords')
nltk.download('punkt')
from nltk.tokenize import word_tokenize
from keras.utils.np_utils import to_categorical
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
with open('/content/gdrive/My Drive/iemocap/train/sentences.pkl', 'rb') as f:
    data = pickle.load(f)
with open('/content/gdrive/My Drive/iemocap/train/labels.pkl', 'rb') as f:
    labels = pickle.load(f)
with open('/content/gdrive/My Drive/iemocap/test/sentences.pkl', 'rb') as f:
    test_data = pickle.load(f)
with open('/content/gdrive/My Drive/iemocap/test/labels.pkl', 'rb') as f:
    test_labels = pickle.load(f)

# %%
def preprocessing(data,labels):
  processed_data=[]
  processed_label=[]
  for i in range(0,len(data)):
    for j in range(0,len(data[i])):
      intermediate_data=[]
      intermediate_label=[]
      for k in range(0,len(data[i][j])):
        text=data[i][j][k]
        if text != '<eos>'and text!='<pad>':
          intermediate_data.append(text)
      processed_data.append(intermediate_data)
  for i in labels:
    for j in i:
      processed_label.append(j)
  return processed_data,processed_label

# %%
#Removes stopwords and punctuations
def cleaning_data(data):
  for i in data:
    i = re.sub(r'[^\w\s]','',i)
    text_tokens = word_tokenize(i)
    tokens_without_sw = [word for word in text_tokens if not word in stopwords.words()]
    new= ' '.join(tokens_without_sw)
    new_sentences.append(new)
  return new_sentences

# %%
processed_data,processed_label = preprocessing(data,labels)
test_processed_data,test_processed_label = preprocessing(test_data,test_labels)

# %%
for i in range(0,len(processed_data)):
  processed_data[i]= ' '.join(processed_data[i])
for i in range(0,len(test_processed_data)):
  test_processed_data[i]=' '.join(test_processed_data[i])

# %%
Y=to_categorical(processed_label, num_classes=6)
test_Y=to_categorical(test_processed_label, num_classes=6)

# %%
processed_data= cleaning_data(processed_data)
test_processed_data= cleaning_data(test_processed_data)

# %%
s=processed_data[0]
s = re.sub(r'[^\w\s]','',s)
print(s)
# Out:
# thank you for calling sprint  we care about everybody  how can i help you

# %%
new_sentences=[]
for i in processed_data:
  i = re.sub(r'[^\w\s]','',i)
  text_tokens = word_tokenize(i)
  tokens_without_sw = [word for word in text_tokens if not word in stopwords.words()]
  new= ' '.join(tokens_without_sw)
  new_sentences.append(new)

print(new_sentences)
# Out:
# ['thank calling sprint everybody help', 'hi phone hour trying get little discrepancy bill fixed charged two hundred', 'sure nt make', 'positive came like another state', 'get phone number please', 'uh yeah gave automated thing like five times', 'going need need look file look file', 'okay three two three six nine seven five zero six six move', 'okay', 'umm miss aruckman', 'seeing two hundred dollar charge', 'yes menus pushed star pound stuff trying', 'well looking', 'charges came like nebraska wherever obviously nt make', 'please refund mischarged charges', 'saying nt make calls', 'make calls bfe nebraska', 'well mean supposed use discretion situation', 'could discretion back', 'right give hundred dollars', 'okay like half', '', 'money charged nt make calls', 'give hundred dollars right fill complaint form', 'go local verizon dealer sprint', 'okay look really trying patient know nt fault know', 'time hour little robot voices telling needed', 'maam understand', 'maam understand understand right telling', 'excuse', 'get money back', 'long', 'weeks nt even know', 'wait weeks people go things get money back nt spend', 'okay know nt feel like anymore money back two hundred dollar', 'yeah fine fine yeah mean nt make difference mean', 'going put back account', 'mean technically policy like mean nt really nobody really cares policy', 'sure', 'oh god thank much', 'welcome', 'really appreciate know policy whatever seriously', 'cool cool cool', 'make life lot easier', 'know mean anything later', 'oh nt know mean nt know thought know maybe get co', 'god like whole problem like mean hey ever', 'ever montgomery mean know call know call operator', '', 'call sprint call center uh know cool', 'alright', '', 'uhm nt know', 'feeling', 'nt know going mean', 'got get job know like', 'lot work right', 'well yea know get resumes mean', 'right fact best', 'go places every place give interview know', 'know nt give hard time best', 'long like waiting probably something else', 'well right', 'nt know mean', 'yea almost like worth know going waste life like trying', 'understand frustrating know really know uh', 'nt even know going worth nt break know like nt nt', 'well mean still tried long think says something', 'yea says stupid enough trying long move somewhere else', 'persistence mean important', 'mean nt nt persistent forever know nt job forever know', 'well talented keep mind know nt give hard time', 'mean maybe know nt job maybe maybe good thought', 'got whole skewed opinion supposed work', 'sorry', 'nt know nt know nt know really know', 'maybe maybe painting nt know know', 'something nt go something stay home nt know', 'seems like option point obviously outer world rejected possible employment', 'mean factors whether good know mean like', 'fact know always different types things kind people office whether male', 'consideration rather giving hard time', 'know mean know either like worst unlucky person', 'nt happen normal person', 'know fact still still cooking like good thinking reconsidering', 'like considering difficult nt mean stop', 'mean nt know nt see nt see way way around right', 'maybe little break nt think stop', 'right thanks talking', 'get letter', 'yes big envelope says know', 'yeah awesome', 'oh god going laughter', 'oh yeah bet really excited oh loans right exactly', 'really excited yeah nt know going pay anything yeah loans', 'oh good good awesome going stay around going like get different neighborhood', 'oh know know know know', 'nt know spend much time commuting rather', 'happy going stay going totally throw party', 'know throw party', 'rapper party yeah okay', 'yeah sticking around thing living glad going', 'relief mean thinking going pack stuff yeah hooray usc', 'yeah big time', 'mmhmm mmhmm yay major', 'yeah sure', 'masters phd nice', 'umm phd laughter', 'good nt like teach class', 'teacher mrs nash question', 'get mold young minds mrs mother', 'get married well married chuck mrs nash confused mrs dash', 'would like oh right righ ...
